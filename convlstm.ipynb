# %%
# %pip install matplotlib tensorflow keras imageio ipywidgets
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.10/site-packages (2.31.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (7.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.4.13)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (6.23.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.6.5)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.7)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.3)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.11.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.7)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.9.0)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets) (0.2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.13)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.17.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from keras.models import load_model, save_model, model_from_json

import io

import imageio
from IPython.display import display
from ipywidgets import widgets, HBox
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fpath = keras.utils.get_file(
    "moving_mnist.npy",
    "http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy",
)
dataset = np.load(fpath)
# Out:
# Downloading data from http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy
# 819200096/819200096 [==============================] - 121s 0us/step

# %%
dataset = np.swapaxes(dataset, 0, 1)

SAMPLES = 1000
dataset = dataset[:SAMPLES, ...]

# Add a channel dimension since the images are grayscale.
dataset = np.expand_dims(dataset, axis=-1)

# Split into train and validation sets using indexing to optimize memory.
indexes = np.arange(dataset.shape[0])
np.random.shuffle(indexes)
train_index = indexes[: int(0.9 * dataset.shape[0])]
val_index = indexes[int(0.9 * dataset.shape[0]) :]
train_dataset = dataset[train_index]
val_dataset = dataset[val_index]

# Normalize to 0-1 range
train_dataset = train_dataset / 255
val_dataset = val_dataset / 255

def create_shifted_frames(data):
    # x is frames 0 to n -1
    x = data[:, 0 : data.shape[1] - 1, :, :]
    # y is frames 1 to n
    y = data[:, 1 : data.shape[1], :, :]
    return x, y

x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)
print(f"Training Dataset Shapes: {str(x_train.shape)}, {str(y_train.shape)}")
print(f"Validation Dataset Shapes: {str(x_val.shape)}, {str(y_val.shape)}")
# Out:
# Training Dataset Shapes: (900, 19, 64, 64, 1), (900, 19, 64, 64, 1)
# Validation Dataset Shapes: (100, 19, 64, 64, 1), (100, 19, 64, 64, 1)

# %%
fig, axes = plt.subplots(4, 5, figsize=(10, 8))

# Plot each of the sequential images for one random data example.
data_choice = np.random.choice(range(len(train_dataset)), size=1)[0]
for idx, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(train_dataset[data_choice][idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

print(f"Displaying frames for example {data_choice}")
plt.show()
# Out:
# Displaying frames for example 40

# %%
def create_model():
    model = keras.Sequential(name="Conv_LSTM")
    
    model.add(
        layers.ConvLSTM2D(
            filters=64,
            kernel_size=(5, 5),
            padding="same",
            activation="relu",
            return_sequences=True,
            input_shape=(None, *x_train.shape[2:])
        )
    )
    model.add(layers.BatchNormalization())
    
    model.add(
        layers.ConvLSTM2D(
            filters=64,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            return_sequences=True,
        )
    )
    model.add(layers.BatchNormalization())
    
    model.add(
        layers.ConvLSTM2D(
            filters=64,
            kernel_size=(1, 1),
            padding="same",
            activation="relu",
            return_sequences=True,
        )
    )
    
    # spatio-temporal
    model.add(
        layers.Conv3D(
            filters=1,
            kernel_size=(3, 3, 3),
            padding="same",
            activation="sigmoid",
        )
    )

    model.compile(
        loss=keras.losses.binary_crossentropy,
        # optimizer=keras.optimizers.Adam(),
        optimizer=keras.optimizers.legacy.Adam(),  # for arm64
        metrics=["accuracy"]
    )
    return model

# %%
EPOCHS = 50
BATCH_SIZE = 5
MODEL_NAME = f"conv_lstm_{SAMPLES}_{EPOCHS}_{BATCH_SIZE}"
MODEL_PATH = f"trained/{MODEL_NAME}.h5"
print(MODEL_PATH)

# load or create model
if os.path.exists(MODEL_PATH):
    print("loading")
    model = load_model(MODEL_PATH)
else:
    print("creating")
    model = create_model()

    model.fit(
        x_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(x_val, y_val),
        callbacks=[
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
            keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)
        ],
    )
    model.save(MODEL_PATH)

model.summary()
# Out:
# trained/conv_lstm_1000_50_5.h5
# creating
# Epoch 1/50
# 2023-10-09 01:56:20.161386: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'Func/gradient_tape/Conv_LSTM/conv_lstm2d_2/while/Conv_LSTM/conv_lstm2d_2/while_grad/body/_555/input/_1530' -> 'gradient_tape/Conv_LSTM/conv_lstm2d_2/while/Conv_LSTM/conv_lstm2d_2/while_grad/body/_555/gradient_tape/Conv_LSTM/conv_lstm2d_2/while/gradients/AddN', 'Func/gradient_tape/Conv_LSTM/conv_lstm2d_1/while/Conv_LSTM/conv_lstm2d_1/while_grad/body/_750/input/_1649' -> 'gradient_tape/Conv_LSTM/conv_lstm2d_1/while/Conv_LSTM/conv_lstm2d_1/while_grad/body/_750/gradient_tape/Conv_LSTM/conv_lstm2d_1/while/gradients/AddN', 'Func/gradient_tape/Conv_LSTM/conv_lstm2d/while/Conv_LSTM/conv_lstm2d/while_grad/body/_945/input/_1765' -> 'gradient_tape/Conv_LSTM/conv_lstm2d/while/Conv_LSTM/conv_lstm2d/while_grad/body/_945/gradient_tape/Conv_LSTM/conv_lstm2d/while/gradients/AddN', 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/mul_2' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/add_5', 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/clip_by_value_2' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/mul_5', 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/convolution_6' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/add_4', 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/clip_by_value' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_367/Conv_LSTM/conv_lstm2d_2/while/mul_3', 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/convolution_6' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/add_4', 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/clip_by_value' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/mul_3', 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/mul_2' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/add_5', 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/clip_by_value_2' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_179/Conv_LSTM/conv_lstm2d_1/while/mul_5'}.
# 180/180 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9183
# 2023-10-09 01:57:49.868492: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/clip_by_value' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/mul_3', 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/convolution_6' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/add_4', 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/mul_2' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/add_5', 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/clip_by_value_2' -> 'Conv_LSTM/conv_lstm2d_2/while/body/_97/Conv_LSTM/conv_lstm2d_2/while/mul_5', 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/clip_by_value' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/mul_3', 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/convolution_6' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/add_4', 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/mul_2' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/add_5', 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/clip_by_value_2' -> 'Conv_LSTM/conv_lstm2d_1/while/body/_49/Conv_LSTM/conv_lstm2d_1/while/mul_5'}.
# 180/180 [==============================] - 96s 477ms/step - loss: 0.1137 - accuracy: 0.9183 - val_loss: 0.3264 - val_accuracy: 0.9287 - lr: 0.0010
# Epoch 2/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0291 - accuracy: 0.9309 - val_loss: 0.2112 - val_accuracy: 0.9287 - lr: 0.0010
# Epoch 3/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0271 - accuracy: 0.9310 - val_loss: 0.1146 - val_accuracy: 0.9303 - lr: 0.0010
# Epoch 4/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0264 - accuracy: 0.9310 - val_loss: 0.0524 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 5/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0259 - accuracy: 0.9310 - val_loss: 0.0370 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 6/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0255 - accuracy: 0.9310 - val_loss: 0.0314 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 7/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0253 - accuracy: 0.9310 - val_loss: 0.0304 - val_accuracy: 0.9325 - lr: 0.0010
# Epoch 8/50
# 180/180 [==============================] - 85s 472ms/step - loss: 0.0251 - accuracy: 0.9310 - val_loss: 0.0305 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 9/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0250 - accuracy: 0.9310 - val_loss: 0.0268 - val_accuracy: 0.9325 - lr: 0.0010
# Epoch 10/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0248 - accuracy: 0.9310 - val_loss: 0.0259 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 11/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0247 - accuracy: 0.9310 - val_loss: 0.0254 - val_accuracy: 0.9325 - lr: 0.0010
# Epoch 12/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0246 - accuracy: 0.9310 - val_loss: 0.0250 - val_accuracy: 0.9324 - lr: 0.0010
# Epoch 13/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0245 - accuracy: 0.9310 - val_loss: 0.0252 - val_accuracy: 0.9325 - lr: 0.0010
# Epoch 14/50
# 180/180 [==============================] - 85s 472ms/step - loss: 0.0244 - accuracy: 0.9310 - val_loss: 0.0250 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 15/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0243 - accuracy: 0.9310 - val_loss: 0.0249 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 16/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0243 - accuracy: 0.9310 - val_loss: 0.0248 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 17/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0242 - accuracy: 0.9310 - val_loss: 0.0248 - val_accuracy: 0.9324 - lr: 0.0010
# Epoch 18/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0242 - accuracy: 0.9310 - val_loss: 0.0247 - val_accuracy: 0.9325 - lr: 0.0010
# Epoch 19/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0242 - accuracy: 0.9310 - val_loss: 0.0247 - val_accuracy: 0.9325 - lr: 0.0010
# Epoch 20/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0241 - accuracy: 0.9310 - val_loss: 0.0247 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 21/50
# 180/180 [==============================] - 87s 484ms/step - loss: 0.0241 - accuracy: 0.9310 - val_loss: 0.0251 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 22/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0241 - accuracy: 0.9310 - val_loss: 0.0249 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 23/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0240 - accuracy: 0.9310 - val_loss: 0.0247 - val_accuracy: 0.9324 - lr: 0.0010
# Epoch 24/50
# 180/180 [==============================] - 87s 485ms/step - loss: 0.0239 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 25/50
# 180/180 [==============================] - 85s 472ms/step - loss: 0.0239 - accuracy: 0.9310 - val_loss: 0.0245 - val_accuracy: 0.9324 - lr: 1.0000e-04
# Epoch 26/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 27/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 28/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 29/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 30/50
# 180/180 [==============================] - 85s 470ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 31/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 32/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 33/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 34/50
# 180/180 [==============================] - 85s 470ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 35/50
# 180/180 [==============================] - 85s 470ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-06
# Epoch 36/50
# 180/180 [==============================] - 87s 482ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-06
# Epoch 37/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-06
# Epoch 38/50
# 180/180 [==============================] - 85s 470ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-06
# Epoch 39/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-06
# Epoch 40/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-07
# Epoch 41/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-07
# Epoch 42/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-07
# Epoch 43/50
# 180/180 [==============================] - 85s 471ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-07
# Epoch 44/50
# 180/180 [==============================] - 87s 483ms/step - loss: 0.0238 - accuracy: 0.9310 - val_loss: 0.0244 - val_accuracy: 0.9325 - lr: 1.0000e-07
# Model: "Conv_LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, None, 64, 64, 64)  416256
#
#  batch_normalization (BatchN  (None, None, 64, 64, 64)  256
#  ormalization)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, None, 64, 64, 64)  295168
#
#  batch_normalization_1 (Batc  (None, None, 64, 64, 64)  256
#  hNormalization)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, None, 64, 64, 64)  33024
#
#  conv3d (Conv3D)             (None, None, 64, 64, 1)   1729
#
# =================================================================
# Total params: 746,689
# Trainable params: 746,433
# Non-trainable params: 256
# _________________________________________________________________

# %%
example = val_dataset[np.random.choice(range(len(val_dataset)), size=1)[0]]

# Pick the first/last ten frames from the example.
frames = example[:10, ...]
original_frames = example[10:, ...]

# Predict new 10 frames
for _ in range(10):
    # Extract the model's prediction and post-process it.
    new_prediction = model.predict(np.expand_dims(frames, axis=0), verbose=1)
    new_prediction = np.squeeze(new_prediction, axis=0)
    predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

    # Extend the set of prediction frames.
    frames = np.concatenate((frames, predicted_frame), axis=0)

# Construct a figure for the original and new frames.
fig, axes = plt.subplots(2, 10, figsize=(20, 4))

# Plot the original frames.
for idx, ax in enumerate(axes[0]):
    ax.imshow(np.squeeze(original_frames[idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Plot the predicted frames
new_frames = frames[10:, ...]
for idx, ax in enumerate(axes[1]):
    ax.imshow(np.squeeze(new_frames[idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

plt.show()
# Out:
# 1/1 [==============================] - 1s 701ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 80ms/step

# %%
examples = val_dataset[np.random.choice(range(len(val_dataset)), size=5)]

predicted_videos = []
mses, psnrs = [], []
for example in examples:
    # Pick the first/last ten frames from the example.
    frames = example[:10, ...]
    original_frames = example[10:, ...]
    new_predictions = np.zeros(shape=(10, *frames[0].shape))

    # Predict a new set of 10 frames.
    for i in range(10):
        # Extract the model's prediction and post-process it.
        frames = example[: 10 + i + 1, ...]
        new_prediction = model.predict(np.expand_dims(frames, axis=0))
        new_prediction = np.squeeze(new_prediction, axis=0)
        predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

        # Extend the set of prediction frames.
        new_predictions[i] = predicted_frame
    
    # Metrics
    mse = np.mean(np.square(original_frames - new_predictions))
    mses.append(mse)
    psnr = 10 * np.log10(255**2 / mse)
    psnrs.append(psnr)

    # Create GIFs for each of the ground truth/prediction images.
    for frame_set in [original_frames, new_predictions]:
        # Construct a GIF from the selected video frames.
        current_frames = np.squeeze(frame_set)
        current_frames = current_frames[..., np.newaxis] * np.ones(3)
        current_frames = (current_frames * 255).astype(np.uint8)
        current_frames = list(current_frames)

        with io.BytesIO() as gif:
            imageio.mimsave(gif, current_frames, "GIF", duration=2)
            predicted_videos.append(gif.getvalue())

predicted_videos
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# [b'GIF89a@\x00@|||zzzsssrrrqqqpppkkkiiihhhgggddd```^^^\\\\\\[[[ZZZXXXTTTSSSRRRQQQPPPNNNGGGCCCBBB@@@???>>><<<;;;999888666333222111000///...---+++***)))\'\'\'%%%$$$###   ,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00%\t\x1cH\xb0\xa0\xc1\x83\x08\x13*\\\xc8\xb0\xa1\xc3\x87\x10#J\x9cH\xb1\xa2\xc5\x8b\x183j\xdc\xc81b$7F~\xb8\x00\x10 \x01\x9b\x8e\x18\xe1P!"\xa0\xe5\x86\x1a-\xb5\xa0\xac\x98\xc7\x86\x81\x96)\x96\xa4Y\x04E@\x81/3)\x92\x100\x02L\x98\x81R\n\x08\xe8\x12t\xe2\x1d\x0f<\xfc\x10\xacb\xa0@\x12HM)\xe6!\xa8\xa7\x83\x00\x16Y)*\x89\x90\x85\x91$G>\x04\x84\x00\x14v"\x1a\t\x02x\xe4\x89!\xe0\xc4\x99\xb6\x14\x8d\x08``A\xc0\x8d@x+\xeep\t8\xf0D=\x1fZ2\xd8bXb#\x17\x02<\xf4\x810@Lc\x88O\x04\x1c\x90Y&\x82\x077\x97\x1db\x100d`\x11\x01;B3,s\xa0\x82\x1a\x8230\xc4Q\xad0\x8b\x80)\x05\x85\xa8\xa5\x9d\x90\xcc\x01\x0b\'\x07\xea\xd6\xc0;\xe1\x05\x01\x10X(Y\xaeB@\x8d\xe2\x08\xdb\xe0@\xd0\xb2:\r\xb3\xd0\x11^\x01\xd2C\x80\r+\x88\xb2\x8b\xd9\x1fO\xbe\xbc\xf9\xf3\x19\x19%\x81Q\x08}A&\x01\x02\xe4p?p\xcd\x82\xf8\x03\xee\xd0\x97\x84$~|;\xfb\xad\xe0\x1f\x07\x83\xec\x97C|\x00(\xb1\x9f$n\xa0\x10\x80\x00^,h\x06\x08\x01\x10\xb1`$E\x04\xe0B#\x0b:\x11\x80\x04{,HG\x05\x01\xc8\xb0`\x1f"\x04\xf0\x03V\xf49B\xe2\x0b\x86\xb8\xf7\x07\x17&8\x10@\x0b\x8a\x0c\xf4H\x14\x82\x8c\xa7\x06\x05\xfe\x05\x90\x05AG\x04\x00`vrL@RI\x01\x98\x90\x88$\x8fL\xd1\x80\x14\x8e\x88\xd7\x84\x7f!\xb0\xa1C\x00A\x10\x82E\x00 \xf0!\x1e\x1e\n\xc4\xf7\xc0\x18\x92(BB\x000\x0c@\x00\x1d\xe3\xd5\x11_\x0c\xe1\tTG\t\x01 @\x05y\x7fd@\xc1!\x05)\xf2\xc6\x1c\x0b\x ...
#  b'GIF89a@\x00@~~~}}}|||{{{zzzyyyxxxwwwvvvuuutttsssrrrqqqpppooonnnmmmlllkkkjjjiiihhhgggfffeeedddcccbbbaaa```___^^^]]]\\\\\\[[[ZZZYYYXXXWWWVVVUUUTTTSSSRRRQQQPPPOOONNNMMMLLLKKKJJJIIIHHHGGGFFFEEEDDDCCCBBBAAA@@@???>>>===<<<;;;:::999888777666555444333222111000///...---,,,+++***)))(((\'\'\'&&&%%%$$$###"""!!!   \x1f\x1f\x1f\x1e\x1e\x1e\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x1a\x1a\x1a\x19\x19\x19\x18\x18\x18\x17\x17\x17\x16\x16\x16\x15\x15\x15\x14\x14\x14\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xcf\xd8\x98S\xc7\xcd\x9a4h\xce\x9c1\xc3\xb0\xa1\xc3\x87\x10#F$Cf\x8c\x980`\xc4\x8c)S\xc6\xcc\x994k\xe2\xc8\x99\xb3F\r$>\x88\x12\x11\n\xf4\xc7O\x9f>|b\xca\x9cI\xb3\xa6\xcd\x9a{\xf4\xe4\xc1s\xc7N\x1d;w\xf2\xe8\xd9\xd3\xe7O A\x83\x08\xf1a\xc3(\x11\xa3E\x86\x04\xb5\x84y\xb3j\xd5\x9cy\xee\xd4\x99\x13\xe7M\x9b\xafn\xe0\x10\xbc\x83G(Q\xa3\x85\x0e%:4\x07\x91"F\x8a\n\tr\xb9\'\xa7\x9e\xbbx\xf3\xea\xdd\xab3k\x1d9\x06\x17\x96!\xe3\x11d\x1b8?\xef\x04\xcd\xc3\xa7\xe8 C\x89\x0c\xc19THe\x1f<s\xe4\xc0y\xe3\xc6\xcd\xd7\xcf\xa0C\x8bf\x93\xa6L\x18-T\x9c(Ir\xa4\x08\x11"F\x9eL\xe12&M\xe7\xdb"\xeb\xe8\xf93\x88\xcf\x99B\x83\x0e\x05\xca3\xc7kI5i\x92+_\xce\x9c\xf9\x991]\xac4A2\xe4G\x0f\x1c1X\xb8hqc\x88\x91(^\xc8\xac\xffi\xa3\xa6d\x1b7q\xec\xec\x19^F\xae\xa1?w\xe2\xb0Y\x93\xd0!\xc7\xfb\xf8\xf3\xdf\x07\xa3\x05\x8a\x11 <\xd4\x80B\t!d\x10\xc1\x05\x1c\xa4\x80\x03\x11N\x84\x87\x86\x1ae(\x04\x92\x1bs\xe0\xe1\x87\x1db\xb8\xf7\x87\x1dp\xb0\xa1F}f\xe8\'b~dp1\xc5\x11A\xd4\xb0\x82\n!\x8c\x10\x02\x05\x0f<\xa0A\x0cA0\x81\x85\x18\x84\xa51\x06\x19\n\xa9\xd1F\x1cw\\\x98\xa1 \x86\xf8Q\xc7\x1b\x07\tF\xd1\x92\x15\xed\xc8\xe4\x93d\x88q\x85\x12@\xd0\x90B\tW\x8ap\x01\x06\x11t@\x83\x11P\\!\x86\x1aj\x90f\x11\x8eg\xa8\xf1F\x1d}\xd4\x11\x86\\\x85\x18\x89d\x1a!69\xc6\x9dx\xe6\xa9\xe7\x9daLQD\x0e-\x90 \x02\t h\x80\x81\x08(\xd8 \xc4\x12P|\x91\x06\x99\x15\x85\x81\x11\x18i\xbaAG\x9bo\x06\x12gA\x1f\xd6y\xa7\x18\xa0\x86*\xea\xa8\xa0\x82!\x85\x101\x9c \x82\t!h\xf0\x01\x08$\xa4\xff\xb0\xc3\x10KLq\x85\x17e$\x04\xc6\x16\xfce1\x86\x8fr\xf0AG\xa6\x9b\xba\xd1i\x93\xa4&;\xaa\xa9?\xc0 \x02\x07(\x88\xa0\x81\x06\x17\x90\x10\x03\x10H<\xc1\x85\x16_\xdc\xf9E\x16Ux\xb1E\x16`\x8c\x17\xc7\x1e\xc3\x16\xa2i\x1ft\x18\x8b\x86\x19\xc8*+/\xb3-x\xa0\x01\x05\x12P\x10A\x06!\x ...
#  b'GIF89a@\x00@{{{vvvuuunnnmmmkkkiiieeebbbaaa```___^^^ZZZXXXWWWVVVUUUTTTRRRPPPOOONNNMMMLLLHHHEEEDDDAAA===<<<:::888777333111///,,,***)))(((&&&%%%$$$###!!!   \x1d\x1d\x1d\x1c\x1c\x1c\x19\x19\x19\x18\x18\x18\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\x17\t\x1cH\xb0\xa0\xc1\x83\x08\x13*\\\xc8\xb0\xa1\xc3\x87\x10#J\x9cH\xb1\xa2\xc5\x8b\x183j\xdc\xc8\xb1\xa3\xc7\x8f C\x8a\x1cI\xb2\xa4\xc9\x93(S\xaa\\\xc9\xb2\xa5\xcb\x970c\xca\x9cI\xf3\xe0\x93\x15_\xbe\x141#\xa7\t\xa0D2\x0f\x15\xd2s$\xc6\x80\x01\x02\x8e*\xc5Q\x05\xcf\xcb\'4\xb6\xacP\x1a\xe1\x83\xd2\xab%\x9c\xb2\xe4\xd3a\x00\x89\xa3&\xa4\xb0A\x94\x05\x86\xd2\x1a?P0a\x99\x88\x8bR\x1b`\x06\r\xdc\x93\xe1\xa8\x8d?w\n\xb5\x04t\xf4A\x8f?\x05\xf1(-\x03\x93\xef\x80\x1c\x05\xdd\xb89r\x94\xc2\x1b\x98I\x06t\x084\x10\x0e!\r\x11 \x1c\r\x12\x93\xc1\x80\x10\x03\xe3\xe4\xa8@ \xe9\x80\nnb\xba\x180\xe1\xf1",JM\x03\x91\tH\x80\x00\x0bE\xdcL\xb1-\x00\x80\x00\t\xaea\n\xf2|5\xf6\x00\x154\xd1\xdcpptF\x94\x07H\x07D\xa9\xb9\xe8L\x96,}\x16]@\x8a\xa0\x0b\xf5\x82\xdb\x15\x8c\xc1\xf9\x0e~@\x03\xf2\x04\xe9h>\x8f^ \x94\xa3\xec\xdb\xbf7\xdf^`\x9a\x06\xf4\xeb\xaf\x8c\x82\xa4H\x80\x00^\xc8\x14\x07\x14y,b\x08\x14<HP\x00o\x02\xf8 \x13\x14\x02l0\x82\x08\x0c2\xa8\x84L_,\xc0 \x0b-\xe8@F\x0c\x02\xec\x00\x94Lah\xe1\xc4\x10Z(2\x10\x0e\x07\xb4\xa1\x9f\x1d $\xa0\xdf"j\x08 \xa3~2\xd88\x90\x15t\xd0\x86\xc5\x1aT\x8c\xf0\xc2\t\x02\x18@\x85\x07\x18\x1c\xd0\x82Ls\x10`A\x85\x1bn!\xd3 b\x88a\x04\x07\xbc\r\x90B\nW\xf8\xf1]\x1dD\xd8\xc6\x83~a\xd8\xb6\x04\x99f\xa2\x89\x81!h\x16 \x05\x9a\x02\x08\x01\xe7\x8d\xed\x95\xa9c}u\x08!\x80 ...
#  b'GIF89a@\x00@~~~}}}|||{{{zzzyyyxxxwwwvvvuuutttsssrrrqqqpppooonnnmmmlllkkkjjjiiihhhgggfffeeedddcccbbbaaa```___^^^]]]\\\\\\[[[ZZZYYYXXXWWWVVVUUUTTTSSSRRRQQQPPPOOONNNMMMLLLKKKJJJIIIHHHGGGFFFEEEDDDCCCBBBAAA@@@???>>>===<<<;;;:::999888777666555444333222111000///...---,,,+++***)))(((\'\'\'&&&%%%$$$###"""!!!   \x1f\x1f\x1f\x1e\x1e\x1e\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x1a\x1a\x1a\x19\x19\x19\x18\x18\x18\x17\x17\x17\x16\x16\x16\x15\x15\x15\x14\x14\x14\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xd1\xdc\xa0c\xe7\r\x1b5i\xd0\xa09\xc3\xb0\xa1\xc3\x87\x10#J\x94\xa80\x8d\x1a6r\xe6\xd0i\xb3&R\x9fD\x8a\n\t\x02\xf4\xc7\x8f\x9f>(S\xaa\\\xc9\xb2\xa5\xcb\x97~\xfe\x00\x124\x88P!?m\x1a)j\xc4\xe8\xd0 \x92\'_\xb6\xe4C\xb4\xa8\xd1\xa3F\x85\xf6\xf13\xd3\x10"E\x88\xe8$Z\xd4h\x91\xa1A%\x89\xee\xd9\xca\xb5\xabW=`\xc3\x8a\x1d;\xd6\xabY>L\t==\x14\x07\x91\xa1\x90~\xf2\xd0\x99\x13\x07\xce\x9b7n\xf2\xea\xdd\xcb\xb7\xaf\xdf\xbf|\xef\xbe\x89#\xc7\xce\x1e@\x84\xfa\xa01\xa4V\x90\x1e:p\xdc\xb0Y\xb3F\x8d\xe5\xcb\x983\xa7\xd9\xcc\xb9\xb3\xe7\xcd\x99CSn\xe3F\xce\x1d>\x82\xf6\x98\xb9z\x08\x10\x1e9m\xd8$th\xa6\xb6\xed\xdb\xb7\xcb\xe8\xde\xcd{7n\xdc\x0e\xd1\xa4Y\xf3\x86N\x9e?w\xc6\xb0\x06t\'\x0e\xc7\xd9g~\xff\xe6M\xa6\xba\xf5\xeb\xd6uK\xb7\xcdP\xf8\x1a7\xc6\x91+\xff\x1ft\xe8\x8f\x1d8\x07\x17\x9a\xa1\x8e\xdd\xfa\x98\xf7b\xe2\xcb\x0fC\xbf\xbe\xfc1\xd9\xaf\xfb6#\xbc\x8d\x1c<~\xd8!\xc6U\x86\x98\x87\x9e\x1a\xd1\x95\xd1\xdeu\xef\x8d1_\x18`D\x18\xe1\x17\x14R\x08F\x18\xf1\xe1\xb7 \x19\xda\x9d\x91\x06Fw\xf8QG\x18\x86\x08R`Ak\xa4\x91`u\r\xb6\x08_|\x10V\xf8\x85\x174\xd6\xe8E\x17^|\x81\xe1{d\xb8\xa8\xa1vh\xb0\x11\xc7\x1d}\x8cX\xe2\x89o\xa4x\x86\x82=\xfa\xe8 \x8c\xf4\x811\xa3\x8d]p\xb1\x85\x16[p\xc1\x85\x17\x17:\xd9`ue\xf0\'$\x91F\x9a(b\x92*2\xe9\xa4|bD9c\x95Vj\xa1\xa5\x96[d\xc9E\x17`\x88\xe1\xe5\x8fb\x0eY$\x89f\xd6\x81\xe6\x92,\xfa\xf8`\x18\x14V\xa9\x05\x96t\xd6i\'\x8dy\xee\tf\x9fd\x02j\xc8\x99J\xaa\xe9"\x9b\x10Jyc\x17]\\)\xe7\x9d\xa1\xde\t\xa9\x9e^N\x1a\xa4\x9fe^*h\xa6\x85\xb6\xff\xf8\xa0\x94\xa0\xdaYk\x9crV\t\xea\x17lf\xf8%\x87\x94\xfey$\xa6i\xc6\xfa"\x8c\x9ef\xe9\xe8\xa2\x8ej\xa9\x05\x9c\\\xe8\xc8\xa6\x8f\xc0\xaeZ\xe9\xb0\xaf\x16\xdbd\x83\x9c\xd2Z\xe7\xa2\x8b\xd2i\xa5\x9dWTAE\x15\xe8^\x81E\x16[\xe0\xb8c\xb5c\n\x1b\xe8\xa0\x9a ...
#  b'GIF89a@\x00@~~~wwwvvvtttsssrrrmmmlllgggeeedddcccbbbaaa```___[[[XXXOOOJJJIIIEEEDDD:::999888777555222***\'\'\'&&&###   \x1c\x1c\x1c\x1b\x1b\x1b\x18\x18\x18\x17\x17\x17\x13\x13\x13\x10\x10\x10\x0e\x0e\x0e\r\r\r\n\n\n,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xc9\x08\x1cH\xb0\xa0\xc1\x83\x08\x13*\\\xc8\xb0\xa1\xc3\x87\x10#J\x9cH\xb1\xa2\xc5\x8b\x183j\xdc\xc8\xb1\xa3\xc7\x8f C\x8a\x1cI\xb2\xa4\xc9\x93\x08\xc3\xd0\xb0\x10\xa0e\x00+(\x13\xc2\x1c\x18\x06\t\x06\x01\x10>4\xa9R%\xa6\xc3\x16\x02\x04\xe4(\xd8%\xc9\x16\x9f\t\xb1<\x10\xa0D\x8c\xc0,. 0\x10\xb0\xc0\x07\xd2\x83_@\x080"\xf0\xc8R\x01)\x968\xd1r\xf5\xa0\x93\x960^\xb4<Qv\xe1\x18&\x07\x04\x04@0cL[\x86\x10\xe4\xce\xb8\xcb\xf0\x06\x01\xb9\x0e\xa8\xf0M\xe8ei\x8c\x0b\x02T\x0cF\xf8#\x80\x06.(\x02\x8cXlp\x8a\x01\x01=\xc8\xa0\x10@\x82r\xc1\xcd\x12\xc0h\xe6\xecy\xa0\x94\x00\x05\x96\x08,A\xba4\x99!\x01"\x08\xb4\x12@@\x10\xd7d6\x00\xe8\x1c&\xc3n\xdc^X\xda SC\x80\x02$\xb8\xc9p\x08\xb0b\xc4\xe5&\xc9\xc9Hi\x10\xd4\x00\x90\xe8\x02q\x08\xa0\x00\x05\xbb\xf7\xef\x10u\x08x\xe8\xf0\xc4{\x93\x04\x03\x04x\x88\x82\xdd\xc2\x80\xf4\x03\x8a`\x97\xf1^\xc0\x00\x11\xd8o\xd4\x1fp\xa1\xfd\xfe\tG\xb9\xe6\x84\x10\x10\xec\xb7\x80\x0cW$\xc7\xc3~\xfdEG\x04\x83\xd8=\x08_\x83\xc9U\x10\x14\x00\x02X\x80\x1d\x0b\x10F\xb7C\x87\xc9\xd17!v!\x80\x88\x9b{#F\x87\xa2}\x14\x9e\xb8\x9f\t\xfe\xc1\'_tP(\x90^\tN\x81\xa7\xe3\x8e<\xf6\xe8\xe3\x8f@\x06)dE\x01\x01\x00,\r\x00\x0c\x00\x15\x00*~~~wwwvvvtttsssrrrmmmlllgggeeedddcccbbbaaa```___[[[XXXOOOJJJIIIEEEDDD:::999888777555222***\'\'\'&&&###   \x1c\x1c\x1c\x1b\x1b\x1b\x18\x18\x18\x17\x17\x17\x13\x13\x13\x10\x10\x10\x0e\x0e\x0e\r\r\r\n\n\nH\xb0\xa0\xc1\x83\x08\x13*\\x0\x0c\r\x0b\x01"\x06\xb0b\x90\xe2\xc00H0\x08\x80\xf0\xa1I\x95*\x0c[\x08\x10\x90\xa3`\x97$[\x10by @\x89\x18\x81Y\\@` `\x81\x8f\x83_@\x080"\xf0\x08K\x01)\x968\xd1\x82\xd0ID\x18/"\x9e`Hf\x0c\x93\x03\x02\x02 \x981\x86\xa9@\x08QgX\x15x\x83@T\x07T\xacza\x19\xe3\x82\x00\x15V\x7f\x0 ...
#  b'GIF89a@\x00@~~~}}}|||{{{zzzyyyxxxwwwvvvuuutttsssrrrqqqpppooonnnmmmlllkkkjjjiiihhhgggfffeeedddcccbbbaaa```___^^^]]]\\\\\\[[[ZZZYYYXXXWWWVVVUUUTTTSSSRRRQQQPPPOOONNNMMMLLLKKKJJJIIIHHHGGGFFFEEEDDDCCCBBBAAA@@@???>>>===<<<;;;:::999888777666555444333222111000///...---,,,+++***)))(((\'\'\'&&&%%%$$$###"""!!!   \x1f\x1f\x1f\x1e\x1e\x1e\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x1a\x1a\x1a\x19\x19\x19\x18\x18\x18\x17\x17\x17\x16\x16\x16\x15\x15\x15\x14\x14\x14\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xdf\xfc\xe0\xe3\xe7\x0e\x1d9q\xe0\xbcY\xc8\xb0aC8\x10!:\x9cH\xb1"\xc48r\xe8\xe8\xd9\xc3\xa7\xce\x9cL\x85"Ir\xa4\x08\xd1!C\x85\n\x11"4\xa8\xa5K\x97\x84R\x1aB\x99\xb2\xa6\xcd\x9b8s\x1a:\x84H\xd1"F\x8d\x0c\xd5\xa9$\xa9\x12\xa5G\x8cL\xa2d9H\x90\xd3\xa7\x82\x06\xb1\x8c\x99s%\xd5\x9cXm\x1a\xea\xe9\x08\x92$H|"M\xaa4\xc9\xd1\xa2\x93,\x9d\x06\x02\x04(\x90\xdb\xb7l\x03\tb\xfa\xb2\xae\xdd\xbbv\tme\xe4\xf5Q\x1eH\x8e$\x05\r\xc4g\x0f\x1e;u\xe8(>\x98\xd0\x8d\xe37n\xe0\xcc\xa1s\xa7re;\x983k\xde\xcc\xd9\x8e\xe5<z\xfc\x0cB\xc4\xa8\x10\x1cG|\x15\r\xeas\xc7\x8e\x1c\x85m\xda\xa49cf\r\x9b6n\xda\xc0\x91\xe38\xced:s\xe6\xc8\x19N\xbc\xb8\xf1\xe3\xc3\x83\xd7\xb1\xa3\xe7\x0f!\xd5n\xcc>J\x14h\x0f\x9d7m\xd8\xac1#\x06\x0c\x992f\xcc\xa0\xff\t\x7ffM\x1b5i\xd8\xb8\x89\x93p\xa1\xe3\xf7\xf0\xe3\xbfw\x08\xc7\xf7\x1d>\x81\x0e\xfdY#=\x11\xa0<t\xc4\x91\xde\x19`x\xe1\x85wf\x9c\x81F\x1a\x0b\xaa\xc1\x06\x1bh8X\x1f\x1c\xf2Uh\xa1\x1b\x0b\xd57\x87\x1d\xf8\xe9\xc7\xdf"\x8f \xf2\x07\x1er\xbc\xa1F\x19cl\xb1E\x17]x\xf1\x9d\x18d\x98\x91\x06\x19i\x84\xc7\xa2\x19\xb8\xc5\x96\xdd\x83<\xf6\xd8\xa3\x8e::V_\x1dz\x00b\x88\x1fjH\'"\x1es\xb8\x81\xc6\x1a`lq\x85\x15atQ\x05\x8c\xe8\xa1q\x86\x18c\x88Q\x86w\xe5\xc5\xe6\xe3\x98d>\x18\x1b\x86qh\xf4\x87!}\xa4!\xdd!\x05\xcd\xf1\xc6\x1ai\x88\x91\x05\x16[d\xf1\x05\x18_x\x81#pk\xa8A\x06\x97_\x84a\x86\x83\xda\xad\xa1\xe8\xa2\x8c6j\x9b\x99m\xbc\x01\x07\x1dy\xfcQH\x9bo\x8e(\'\x1b3\xf6\xe9E\x17_l\x01\x86\x8c\x93\xb1AF\x16ND\x01\x05\x16XX1j\x1aj8\xff*+\xa3<\xe26i\xa5\x97\xba\t\xa2~L\xbe\xc1\xc6\x19a\x88q`\xabV$x"\x19Q2\x91\x84\x11F41\x85\x15]\x84QF\x84j\xc4:\xab\xa3fFF\xa9\xa5\x98\xee\xaa)\x1ckl\t\x06\x17UDqE\x19i\xac\xa1E\x17W4Qn\x13N\x1c\xd1D\x13K`\xa1\'\xba\xd5Z{\xed\xa2\xd9\xde\xca\xad\xae\x8f\xf0:\x07\xb8f\x8c\ ...
#  b'GIF89a@\x00@xxxvvvuuutttsssnnnhhhfffdddccc___]]]\\\\\\[[[XXXVVVUUUTTTSSSRRRQQQPPPMMMKKKJJJIIIHHHEEEDDDAAA@@@===<<<:::999888666111///---,,,+++***(((&&&$$$###!!!   \x1e\x1e\x1e\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x1a\x1a\x1a\x16\x16\x16\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\x1d\t\x1cH\xb0\xa0\xc1\x83\x08\x13*\\\xc8\xb0\xa1\xc3\x87\x10#J\x9cH\xb1\xa2\xc5\x8b\x183j4h\xe6\xc7\n\x00\x05r\xe4\xe0\xb2Qc"/\'\x06\x04X\xc9r\x80\x8eB%/JaI\x93&\x9a\x98\x16\r\xac$\x91\xc4\x0e#?4\t,\xc19\xf1\x8dJ\x10\x8b\x06"\x12\xf3\x82\xa5\x038D#NY\x19\xc6 \xa1\xa6+\xa9D\x85\x08F@\x80\x03W\n\xe2\xe1\xb0R@\xd5\xad\x0f!\xacLpC\x91\xa3Fl(\xb0\xfc\x80\x16\xa2\x9c\r,ih)B\x93\xc1\x98\xba\x10\x13e\x99Ps\xe5\x894\x80%v\xa9I\x00G\xa0\xc4\x11\xd5\\\xa8\xa9\x04r\xc4":k\xd6\xb1\xfc\xd0\x06\x82\x95\x08b\xd4X9\x943C>\x04V\xa6\x10\xe4\xa8N\x83\x00@L3\xfc\xc1\xf2\xcf@\x0f\x016\xc8^\xc8\x83\xe5\x08$N\x8e,\xc8\xbd[\xe1\x18\xaf\x85\x89\x17Oh\x85\x86\x05\x95,\x17|Y\xce\xf0\x0c\x10\x16\x012L\xa7\xce\xbd\xbb\xf7\xef\xe0\xc3\x8b\xec\x1fO\x9e\x0e\x0f\x17\x08z\xf4\xa8\x92g<\xa0\x14\xc3\x05 \xa8\xe0\xb5D\xa2\xf0\x88d\x08\x10\x00\x83\x8a\x9fAL\xcc`\x84!\xe1]\xb1\x9f\x00$\x917\x90\x81\x02p\xa0\xa0R!\xac\xd4\xc3\x83\x02\xc1q\xe0_\x14\x06q`\x1c\x025\xd2\xc7\x87i\x14!\xa2\x88zP\xd7\xc3\x81Q\x90QF\r\xfb\x05 \x80\t*\xa8 \x82|P\x10\xb8\xdb\x89\x07\xba\xb8\x1f\x07=\x8c\xc1\x88@\x89\xe8\xb0\x9f\x15\xc5\tA\x93\x04\x19,A\xc7AM\xac4Dq\x86@QC\r[\xec\x91\x90 \x19\xec\xc7\xe1\x83\x87\xa0 \xc0\x02O\xfc\xa8 \x1c-\x04\x10\x01\x11\x0f\xd2\xa1D\x03\x028\xb0\x86\x82th\x10\x00\x00\n\xd4\xe0\x06yp\xec\x10_\x08m\x8cw\x08\x16\x1d, ...
#  b'GIF89a@\x00@~~~}}}|||{{{zzzyyyxxxwwwvvvuuutttsssrrrqqqpppooonnnmmmlllkkkjjjiiihhhgggfffeeedddcccbbbaaa```___^^^]]]\\\\\\[[[ZZZYYYXXXWWWVVVUUUTTTSSSRRRQQQPPPOOONNNMMMLLLKKKJJJIIIHHHGGGFFFEEEDDDCCCBBBAAA@@@???>>>===<<<;;;:::999888777666555444333222111000///...---,,,+++***)))(((\'\'\'&&&%%%$$$###"""!!!   \x1f\x1f\x1f\x1e\x1e\x1e\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x1a\x1a\x1a\x19\x19\x19\x18\x18\x18\x17\x17\x17\x16\x16\x16\x15\x15\x15\x14\x14\x14\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xd1\xdc\xa0c\xe7\r\x1b5i\xd0\xa09\xc3\xb0\xa1\xc3\x87\x10#J\x94\xa80\x8d\x1a6r\xe6\xd0i\xb3&R\x9fD\x8a\n\t\x02\xf4\xc7\x8f\x9f>(S\xaa\\\xc92%\x1f=x\xec\xd0\x91\x03\x07N\x1c9u\xee\xe8\xe1\xd3\xd2\xcf\x1f@\x82\x06\x11*\xe4\xa7M#E\x8d\x18\x1d\x1aD\xf2d\xcb\xa7+\xf9\xf0\xd9\x93\xa7N\x9c6i\xce\x94!Cf\x0c\x993k\xe2\xd4\xc9#u\xa5\x1f\xa0\x86\x10)BD\'\xd1\xa2F\x8b\x0c\r*)u\x8f\xdd\xbbx\xf3\xe6\x85Y\xe7M\x9a0[\xaeHy\xd2d\xc9\x12\'T\xb6\x90iC\x07\x8f\x9e\xbc|\xce\x12R{(\x0e"C!\xfd\xe4\xa13\'\x0e\x9c7o\xdc\x88\x1eM\xba\xf4\xe85f\xbcPA\x02D\xc7\x8c\x15+L\xa0 Q\xe2\x04\x8d P\xbc\x9ci\x03\x1a\xb4M9v\xf6\x00"\xd4\x07\x8d\xa1\xc9\x82\xf4\xd0\x81\xe3\x86\xcd\x9a5j\xa2K\x9fN]z\x9a1[\x9a\x08\xa9a\xc2\x83\x06\t\x14,@\xffh\xb0@B\x87\x139\x9ep)\xa3\xe6\xf9\xf36n\xe4\xdc\xe1#h\x8f\x19\xb9\x87\x00\xe1\x91\xd3\x86MB\x87f\x04(\xe0\x80\x04\x96\xa1E\x13=\xac\xe0A\x04\x17p\xf0A\x07\x1bl\x90\xc1\x05\x0c\x9e\xf7C\x14]\x94\x91FBh\xb4\xf7\x06\x1dy\xfcq\xc7\x18\xf8\x01r\xc7Uk\xfcw\x06\x81,\xb2(\x06\x15D\xc4\xf0\xe0\x05\x1e\xa0pB\x08\x1bh\xc0\xc1\x05\x14H\xc0\x01\n90\xa1\xc5\x18\xd1m\x98\xc6\x1an\x80("\x89\x83\x1c\xf2\x87\x1dp\x1c\xb4\x90\x19eTi%WXf\x89\xa5\x17N\xf8p\xc2\x06\x17t\xb0\x02\x08\x1a\x94P\xc2\x08)h0\x81\x06\x19\xa0\xb0\x02\x11U\x80q\x06B\n\xa9\xd1\x86\x1cx\xf8a\x87\x18r\x19\xf2d\x94j\xac\xb8\x95\x96\x84\x12\xba\x85\x129\x84\x80\x81\x04&\x8c\xe0\x81\x07!h\xa0\x01\x04\x10`p\xc1\x07+\xcc \x04\x16\xbaAW\xe7\x9dy\xd6\x11\x86!\x82\xf8YP\x8a\x82r5\xc6\xaa\xac\xb6\xea\xea\x18Z(\xffAC\x08\x16L\x90B\x0b3\x84\xc0A\x04\x0f8\xd0\x00\x06%\xb8\x80\xc3\x0eI`\x01\x86\x86\x08Yt\xe7\x1d}\x88J\xaa\xa9o\xa0:\xe8\xab\xd4\xb6\x1a\xeb\r |\xf0\x00\x0b5\xc8\xd0\xc1\x04\x0b$`@\x01\x1a\xb4\x80C\x11B<a\x85\x17e(\x84\x86\xb2\xf25;j\xa9~\xf4%\x ...
#  b'GIF89a@\x00@zzzwwwttthhheeeYYYXXXUUUPPPNNNMMMBBBAAA>>><<<888333,,,&&&$$$###\x1f\x1f\x1f\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x18\x18\x18\x17\x17\x17\x13\x13\x13\x10\x10\x10\r\r\r\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xab\x08\x1cH\xb0\xa0\xc1\x83\x08\x13*\\\xc8\xb0\xa1\xc3\x87\x10#J\x9cH\xb1\xa2\xc5\x8b\x183j\xdc\xc8\xb1\xa3\xc7\x8f C\x8a\x1cI\xb2\xa4\xc9\x93(S"\x94\x92b\x05\x8f%*#\x06\x11@\xf3\xc1\x88\x98\x0fg\xd2\xa4\xd9\xe2\x08N\x86JLP`@3\x80\t&?\x1b:\xc1q!\x80\x00\x1aI\x1d.q\xaa"*C*@\x9c\xda\xb0\xbap\x87\x80\x00\x06\x8apU\xe85\xc0\x82\x1ec\x13\x0eI\xe0t\x03\x06\x11/\xe2\xbeX\xe1$m\x95),\x068\x1d\xc0W\x00\xdf\x0fv\x91\xf0\x1d\xe0\xb7/\xdf\x08vC\x0c.Lxp\xda\'\x00h\x8a\x10\xe0\xa2\xa0\x90\xb1M:\xf8\xe5`A\x80\x06\xbb\x04I4\xd6!A\x00\x05\x98v\x9f\x80 @\xb3\x80\x02\x9a\x95AW)Q4\xb2\x00\x04FdW1A\xf8+M\xa8\xba\x89\xc8 \xbc\xf7\x86n\x81P\x92(\xcf0\xe0\xc4\xf1\x829\x04\x84\x80\xf2| \x8a\x01\r\x92T\x87\x82\x02\xc1\x00\x06\xda\x8f\xdbD\x800XD\x94\xb1Njx8\xe0\xb4(\xcd\x0cv+,\x9e\xef \xf6\xd8\x19\x13\x0c\xf7\xe5\xf0Cv\x13\x1f1\xc0\x10\xc3\x80;\x9cW\xdd\x81\x08&\xa8\xe0\x82\x0c6\xe8\xe0\x83\x10F(\xe1\x84\x14Vh\xe1\x85\x18f\x98a@\x00,"\x00\x0c\x00\x14\x00!~~~zzzwwwvvvtttssshhheeeYYYXXXUUUPPPNNNMMMJJJBBBAAA>>><<<;;;888666555333---,,,\'\'\'&&&$$$\x1f\x1f\x1f\x1c\x1c\x1c\x1b\x1b\x1b\x18\x18\x18\x17\x17\x17\x13\x13\x13\x10\x10\x10\r\r\r\n\n\n\t\t\tpA\xe4\x8a\x98\x83\x08\x13*\\"\xa0a\x84\x12\n#"d\xd8\xb0!\x0c*\x12\x15Z9q\xc1A\xc3\x00\'\xb0d\x8c\xa8\x05\x88\x86\x00\x02v\x8c\x94x\x05e\x8b\x95\n\xc3$A\xe9\x03f\xc2!\x02\x02 \x98b\x13!\xce\x00\r\x8c\xf4<\x08e\x01\xca\x0e`\x86\x1e\xbca \x80\x08\xa5\x07\x99X \x80\x04\xaa\x18\x14\x02\x80Xe! \xc6\x87\r$d\x88\x95\xe1BK\xc6\x0c\x02\x06\x0cH\xab\x96-\x08\x84Et\xfc\x88 ...
#  b'GIF89a@\x00@~~~|||{{{zzzyyyxxxwwwvvvuuutttsssrrrqqqpppooonnnmmmlllkkkjjjiiihhhgggfffeeedddcccbbbaaa```___^^^]]]\\\\\\[[[ZZZYYYXXXWWWVVVUUUTTTSSSRRRQQQPPPOOONNNMMMLLLKKKJJJIIIHHHGGGFFFEEEDDDCCCBBBAAA@@@???>>>===<<<;;;:::999888777666555444333222111000///...---,,,+++***)))(((\'\'\'&&&%%%$$$###"""!!!   \x1f\x1f\x1f\x1e\x1e\x1e\x1d\x1d\x1d\x1c\x1c\x1c\x1b\x1b\x1b\x1a\x1a\x1a\x19\x19\x19\x18\x18\x18\x17\x17\x17\x16\x16\x16\x15\x15\x15\x14\x14\x14\x13\x13\x13\x12\x12\x12\x11\x11\x11\x10\x10\x10\x0f\x0f\x0f\x0e\x0e\x0e\r\r\r\x0c\x0c\x0c\x0b\x0b\x0b\n\n\n\t\t\t,\x00\x00\x00\x00@\x00@\x00\x00\x08\xff\x00\xc7\xc8x\x13G\xcd\x992d\xc6\x8c\x11\xc3\xb0\xa1\xc3\x87\x10\x1f\x86\x99H1\x0c\x98\x8b\x17)6TH\xa6\xcc\x996n\xde\xa01\xc3\x08\x0f\xa1B\x80\xfa\xec\xd1\x93\'\x0f\x9e\x970c\xca\x9c)\xf3\x8e\x9d\x9bur\xea\xccy\xf3\xce\x9d\x97-\xf5\xec\xe9\xe3\xe7\x0f\xa0<h\x10\x15BtH\x90\x9f\x95.iJ\x9d\xea\xd3N\x1d:s\xe4h\xdd*g\x0e\x9d:=a\xe6\x19\x1ahP\xa1Ao\x08\x19Bd(\x90\x1f\x96Uo\xca\x9dK\xb7.\xce\xabY\xe3\xc0\x89\x13G\x0e\xdf\xbfZ\xe7\x80\x95{g\xec\x1f\xb3\x82\xd8\x0c\n\x842\x0f\x9d7n\xd8\xacQ\xa3&\x8d\xe5\xcb\x983kN\x83\xe6\x8c\x192\x1d\xcd\x98\xf1,\x1a!\x193\x1e\xd3\xa8Y\xb3\x86M\x9b8v\xf6\xfc\xc13&\xd0\xe1>u\xde\xacIC\xba\x8c\xef\xdf\xc0\x83\x0bG8&\xcc\x97/`\xbcx\xc1\xf8\xc5K\x97.\xcb\xc1\x84!s\xa6:\x9a4l\xe4\xdc\xe9c\'\x8c[A{\xe6\xb4\xff\xe9\x9c\xd0a\xc5\xf3a\xcc7\xb4\xd8\x85\x0b\x97-X\xb2py\xee~K\x16-Z\xb6<\x073\x06\xf4\xe94o\xd0\xa1\x87\x1c^|\xb7\x87\x1cl\x8cT\x9e\x18\xe85\xd8`r\xefia\x85\x15YT\x98\x05\x16WLx\xc5\x15\xfa\xe9\'\x86\x7ff\xa4\xe1\x86\x80\x04~\xa7G\x1ck\x1c\xb4\x90E\x18\xb5\xe8\xe2\x8b\xcdu\xb1\x85\x16YXA\x05\x15SH\x11E\x8eQ\xf4\xb8#\x87\xf7y\xc1P\x7fh\xb41G\x1eqt\xe1V \'\xa6X\x06\x83`\x1c\'\xe5\x94TR\xe9\x9c}VL\xb1D\x12F\x0cQ\xc4\x11J0\xd1D\x13O\xecHE|Xp\x91^\x7f\x1f\xc9\x91\x07\x1c\\\x04\xd2\x07\x93\x05}\x06\xe5q\xca\xe5\xa9\xe7\x9ex\xb6w\xa1\x14L\x1c!\x04\x0f:\xe4\xd0\x03\x10H,Q\xa6\x14S\x9c\xa9\xc5\x15Y|\x91\x1eu\xd9\xe1\x01\xa7\x9ct\xaaag\x94\xcd\xed\xe9\xa9\xa7\\\xe0w\xc5\x12E\x00\xd1\x03\x0e5\xcc\xe0\x02\x0c8\x04\x81\xc4\x13RH\xffA\x85\x154f\xd1\xc5\xa4gTz\xe9\x9cojJ\x86\x18\x9c~*l\x9e\xf6e!E\x11>\xf0\x10\x03\x0b)\x84\xa0A\x07.\xd4\x00D\x12\xb0\xea\x08\xe9\x15Z\x80\xf1a\xaerX\x1a\'\xafp\xf8\n,\x9e\xc3~\xfa^\x8dP\x08q\x03\r%lP\xc1\x04\rh`\x02\x0e> \x11\x05\xadX\xe4W\xa1\xb6\ ...

# %%
print(" Truth\tPrediction")
for i in range(0, len(predicted_videos), 2):
    box = HBox(
        [
            widgets.Image(value=predicted_videos[i]),
            widgets.Image(value=predicted_videos[i + 1]),
        ]
    )
    display(box)
# Out:
#  Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf6\…

# %%
plt.plot(psnrs)
plt.plot(mses)
